# %%
import ingredient_preprocessor as ip
import ingredient_indexing as ingredient_indexing
from food_ranker import *
import food_indexing as food_indexing
import food_preprocessor as fp

# %%
ingredient_tokenizer = ip.SplitTokenizer()
ingredient_tokenizer.tokenize("This is a test sentences, with a comma...., chicken breasts")
# Out:
# ['this is a test sentence', 'with a comma', 'chicken breast']

# %%
stopwords = set()
with open('stopwords.txt', 'r', encoding='utf-8') as file:
    for stopword in file:
        stopwords.add(stopword.strip())
f'Stopwords collected {len(stopwords)}'
# Out:
# 'Stopwords collected 610'

# %%
dataset_path = 'cleanedRecipes.jsonl'
# stopwords = {'and', 'the', 'or', 'is', 'for'}
text_key = 'NER'
doc_augment_dict = {}
food_preprocessor = fp.RegexTokenizer('/w+')
minimum_word_frequency = 5

# %%
# preprocessor = RegexTokenizer('\w+', lowercase=True, multiword_expressions=None)
ingredient_index = ingredient_indexing.Indexer.create_index(ingredient_indexing.IndexType.InvertedIndex, dataset_path='cleanedRecipes.jsonl', document_preprocessor=ingredient_tokenizer, stopwords=stopwords, minimum_word_frequency=0, text_key='NER', max_docs=750000)
print(ingredient_index.get_statistics())
# Out:
# 0it [00:00, ?it/s]
# 2231142it [00:13, 170732.47it/s]
#  34%|███▎      | 750000/2231142 [00:22<00:43, 34051.13it/s]
# Counter()
#  34%|███▎      | 750000/2231142 [00:26<00:51, 28803.88it/s]
# defaultdict(<class 'collections.Counter'>, {'index_type': 'BasicInvertedIndex', 'unique_token_count': 45465, 'total_token_count': 5483334, 'number_of_documents': 750000, 'mean_document_length': 7.311112})

# %%
preprocessor = fp.RegexTokenizer('\w+', lowercase=True, multiword_expressions=None)

food_index = food_indexing.Indexer.create_index(food_indexing.IndexType.InvertedIndex, dataset_path='cleanedRecipes.jsonl', document_preprocessor=preprocessor, stopwords=stopwords, minimum_word_frequency=15, text_key='directions', max_docs=750000)
# Out:
# 2231142it [00:12, 180529.55it/s]
#  34%|███▎      | 750000/2231142 [00:18<00:36, 40991.86it/s]
# Counter({'1': 4260832, '2': 2238922, 'and': 1992308, 'c': 1894620, 'in': 1052908, 'tsp': 878796, '4': 841644, 'to': 823152, '3': 723315, 'sugar': 648442, 'add': 628456, 'with': 559730, 'mix': 522362, 'salt': 508105, 'until': 504787, 'minutes': 499315, 'of': 488682, 'or': 487901, 'a': 476608, 'for': 465511, 'tbsp': 462665, 'cheese': 454066, 'cream': 408367, 'butter': 405788, 'oz': 401687, 'the': 399359, 'chopped': 395072, 'flour': 386553, 'can': 383812, 'bake': 371389, 'u00b0': 365861, 'water': 344739, 'at': 343134, 'into': 342636, 'pepper': 317509, 'milk': 315870, 'onion': 299325, 'eggs': 293049, 'on': 283856, '8': 269064, 'chicken': 269048, 'ingredients': 261706, 'over': 257350, 'pour': 238178, 'vanilla': 234345, 'lb': 233859, 'mixture': 229426, 'baking': 229322, 'pan': 227562, 'large': 222719, 'stir': 221215, '350': 218851, 'brown': 216722, 'well': 216501, 'pkg': 211336, 'cook': 201389, 'inch': 198996, 'sauce': 195155, 'all': 184288, 'soup': 183336, 'top': 182742, 'oil': 182387, '6': 179532, 'egg': 179466, 'heat': 179249, 'margarine': 176534, 'cake': 169454, 'cool': 168119, 'together': 165919, 'juice': 161286, 'combine': 160881, 'small': 160424, 'cut': 155334, '10': 153763, 'place': 148877, 'powder': 148237, 'pie': 145969, '5': 139782, 'green': 138043, 'medium': 137414, 'oven': 137225, 'bowl': 131406, 'garlic': 126754, 'beat': 124671, 'bread': 122448, '9': 122119, 'x': 121423, 'casserole': 120553, 'cover': 118787, 'dish': 118109, 'chocolate': 117705, 'cup': 117316, 'beef': 116657, 'hot': 116018, 'soda': 115956, 'sliced': 114895, 'put': 114608, 'nuts': 114400, 'lemon': 113889, 'about': 113784, 'onions': 112876, 'sprinkle': 111833, 'pineapple': 106625, 'ground': 106130, 'rice': 105875, 'potatoes': 105764, 'serve': 105637, 'melted': 104728, 'then': 104224, 'celery': 102721, 'dry': 102289, 'sour': 100778, 'is': 100418, 'drain': 99167, 'cinnamon': 97721, 'grated': 97700, '30': 96896, 'corn': 95176, 'boil': 94808, 'salad': 93659, 'from': 91950, 'meat': 91212, 'greased': 90816, '15': 90543, 'cooked': 90234, '12': 89932, 'remaining': 88818, 'spread': 88630, 'hour': 88539, 'remove': 88187, 'let': 87591, 'drained': 86121, 'beans': 82693, 'tomatoes': 81962, 'hours': 81309, 'taste': 81177, 'whip': 80216, 'tomato': 79884, 'crushed': 78614, 'beaten': 77871, 'crumbs': 77839, 'vinegar': 77454, '20': 77060, 'frozen': 74564, 'stick': 73077, 'pecans': 72658, 'roll': 72579, '13': 69883, 's': 69356, 'white': 69298, 'set': 69203, 'each': 68732, 'chips': 68682, 'makes': 67036, 'cans': 66505, 'diced': 65786, 'shredded': 65539, 'pieces': 65477, 'shortening': 65386, 'simmer': 64420, 'broccoli': 62610, 'slices': 62219, 'fresh': 62071, 'cheddar': 62061, 'chill': 61989, 'blend': 61610, 'pudding': 61176, 'if': 61009, 'half': 60683, 'layer': 60320, 'bacon': 59703, 'tender': 59430, 'stirring': 59315, 'mayonnaise': 59083, 'melt': 58691, 'up': 58613, 'boiling': 57993, 'coconut': 57818, 'box': 56485, 'it': 54494, 'cups': 53629, 'orange': 53546, 'low': 53309, 'red': 53229, 'as': 52633, 'peanut': 52449, 'parsley': 52259, 'dough': 51994, 'crust': 51868, 'skillet': 51600, 'mustard': 51546, 'mushroom': 50889, 'not': 50885, '45': 50396, 'mushrooms': 50218, 'cookie': 50135, 'before': 49572, 'out': 49307, 'be': 49163, 'sheet': 48765, 'refrigerate': 48562, 'carrots': 48484, 'fruit': 48336, 'sweet': 48240, 'bring': 47844, 'cookies': 47131, 'dressing': 46905, 'broth': 46793, 'sausage': 46558, 'use': 46029, 'noodles': 45842, 'crackers': 45661, 'are': 45447, '16': 45224, 'optional': 45116, 'make': 45115, 'lightly': 44931, 'saucepan': 44482, 'serving': 44269, 'one': 43951, 'smooth': 43912, 'oleo': 43812, 'bottom': 43572, 'chili': 43195, 'minced': 43056, 'powdered': 43000, 'warm': 42622, 'whole': 42580, 'syrup': 42367, 'when': 42182, 'spoon': 41947, 'dip': 41814, 'apples': 41599, 'done': 41171, 'jar': 41119, '375': 41055, 'vegetables': 40902, 'raisins': 40794, 'first': 40637, 'cloves': 40540, 'peppers': 40192, 'cold': 40061, 'parmesan': 39716, 'vegetable': 39216, 'you': 386 ...
#  34%|███▎      | 750000/2231142 [00:17<00:35, 42236.32it/s]

# %%
food_index.get_term_metadata('chicken')
ingredient_index.get_term_metadata('chicken')
# Out:
# {'term_freq': 649, 'term_total_count': 662}

# %%
topQ = ingredient_index.get_postings('king')
ingredient_index.get_postings('king')
# Out:
# [(10800, 1), (14591, 1), (74649, 1)]

# %%
for q in topQ[:2]:
    with open('cleanedRecipes.jsonl') as f:
        for line in (f):
            json_record = json.loads(line)
            if q[0] == json_record['recipeID']:
                print(json_record)
                json_record['ingredients'] = json.loads(json_record['ingredients'])
                json_record['NER'] = json.loads(json_record['NER'])
                print(json_record)
                print(json_record['ingredients'][0])
                # print(json_record['directions'])
               
                # print(json_record['title'])

    print(q)
# Out:
# {'recipeID': 10800, 'title': 'Bread Pudding', 'ingredients': '["1 king size loaf bread (stale)", "2 cans evaporated milk", "2 cans water", "1 1/2 c. sugar (more or less to taste)", "4 large eggs", "1/2 tsp. margarine", "1 tsp. vanilla", "3/4 c. raisins (soak in water first)", "nutmeg", "guava paste* (optional)"]', 'directions': 'Soak bread in milk and water. Add sugar and eggs. Mix well. Add vanilla and raisins. Pour into greased 9 x 13-inch pan. Sprinkle nutmeg on top. Pat pieces of margarine over the pudding. Bake at 350\\u00b0.', 'link': 'www.cookbooks.com/Recipe-Details.aspx?id=381317', 'source': 'Gathered', 'NER': '["king", "milk", "water", "sugar", "eggs", "margarine", "vanilla", "raisins", "nutmeg", "guava paste"]', 'website': 'www.cookbooks.com'}
# {'recipeID': 10800, 'title': 'Bread Pudding', 'ingredients': ['1 king size loaf bread (stale)', '2 cans evaporated milk', '2 cans water', '1 1/2 c. sugar (more or less to taste)', '4 large eggs', '1/2 tsp. margarine', '1 tsp. vanilla', '3/4 c. raisins (soak in water first)', 'nutmeg', 'guava paste* (optional)'], 'directions': 'Soak bread in milk and water. Add sugar and eggs. Mix well. Add vanilla and raisins. Pour into greased 9 x 13-inch pan. Sprinkle nutmeg on top. Pat pieces of margarine over the pudding. Bake at 350\\u00b0.', 'link': 'www.cookbooks.com/Recipe-Details.aspx?id=381317', 'source': 'Gathered', 'NER': ['king', 'milk', 'water', 'sugar', 'eggs', 'margarine', 'vanilla', 'raisins', 'nutmeg', 'guava paste'], 'website': 'www.cookbooks.com'}
# 1 king size loaf bread (stale)
# (10800, 1)
# {'recipeID': 14591, 'title': 'No Cook Recipe', 'ingredients': '["Burger King", "McDonald\'s", "Pizza Hut", "Denny\'s", "Arby\'s", "Wendy\'s", "Taco Bell"]', 'directions': "Load family (husband included) into family vehicle (van preferably for separating kids). Drive to nearest location (can't stand kids for any longer) and release kids on the establishment (hopefully there's a playground). When food is gone (whether in stomachs or on floor) leave to the relief of others sitting around you. Oh! Don't forget your coupons!", 'link': 'www.cookbooks.com/Recipe-Details.aspx?id=740791', 'source': 'Gathered', 'NER': '["King", "\'s", "Hut", "\'s", "Wendy\'s", "Bell"]', 'website': 'www.cookbooks.com'}
# {'recipeID': 14591, 'title': 'No Cook Recipe', 'ingredients': ['Burger King', "McDonald's", 'Pizza Hut', "Denny's", "Arby's", "Wendy's", 'Taco Bell'], 'directions': "Load family (husband included) into family vehicle (van preferably for separating kids). Drive to nearest location (can't stand kids for any longer) and release kids on the establishment (hopefully there's a playground). When food is gone (whether in stomachs or on floor) leave to the relief of others sitting around you. Oh! Don't forget your coupons!", 'link': 'www.cookbooks.com/Recipe-Details.aspx?id=740791', 'source': 'Gathered', 'NER': ['King', "'s", 'Hut', "'s", "Wendy's", 'Bell'], 'website': 'www.cookbooks.com'}
# Burger King
# (14591, 1)

# %%
len([word for word in ingredient_index.index.keys() if len(word.split(" ")) > 1])
# Out:
# 3894

# %%
from importlib import reload
import food_ranker
reload(food_ranker)
from food_ranker import *

# %%
ranker = Ranker(food_index, ingredient_index, preprocessor, ingredient_tokenizer, stopwords, BM25)

# %%
topq = ranker.query(query_ingr='pie, flour, cream, apples, blueberries', query_freetext='sweet and spicy pie', query_NOT='eggs, pecans, nuts, almonds')[:10]
# Out:
# pie, flour, cream, apples, blueberries sweet and spicy pie
# ['pie', 'flour', 'cream', 'apples', 'blueberries', 'sweet', 'spicy', 'pie']
# egg
# pecan
# nut
# almond

# %%
topq
# Out:
# [(425925, 25.34135345376678),
#  (8257, 25.210549426069004),
#  (408763, 24.203660992767674),
#  (293926, 23.88519285061779),
#  (124486, 23.37641882805338),
#  (227756, 23.06351051048317),
#  (190623, 23.011949882834326),
#  (522343, 22.993799671156218),
#  (568638, 22.937364936462494),
#  (233308, 22.77059654701253)]

# %%
track = 0
for q in topq:
    track = 0
    with open('cleanedRecipes.jsonl') as f:
        for line in f:
            json_record = json.loads(line)
            if q[0] == json_record['recipeID']:
                # print(json_record)
                json_record['ingredients'] = json.loads(json_record['ingredients'])
                json_record['NER'] = json.loads(json_record['NER'])
                print(json_record)
                print(json_record['ingredients'][0])
                print(json_record['NER'])

            track += 1
            if track == 750000:
                break
                # print(json_record['directions'])
               
                # print(json_record['title'])

    print(q)
# Out:
# {'recipeID': 425925, 'title': 'Sugarless Apple Pie', 'ingredients': ['1 (6 oz.) can concentrated apple juice', '2 Tbsp. cornstarch', '1/2 can or 3 oz. water', '1/2 tsp. apple pie spice', "1 pkg. Sweet 'N Low", '2 c. apple slices'], 'directions': "Mix all ingredients until thick, then slice apples. Put in an uncooked pie crust or you may just pour over apples in a pie pan and cook. You can sprinkle Sweet 'N Low over apples and mixture if you want. Bake for 45 minutes at 350\\u00b0. Makes 1 pie.", 'link': 'www.cookbooks.com/Recipe-Details.aspx?id=428253', 'source': 'Gathered', 'NER': ['apple juice', 'cornstarch', 'water', 'apple pie spice', 'N', 'apple slices'], 'website': 'www.cookbooks.com'}
# 1 (6 oz.) can concentrated apple juice
# ['apple juice', 'cornstarch', 'water', 'apple pie spice', 'N', 'apple slices']
# (425925, 25.34135345376678)
# {'recipeID': 8257, 'title': 'Ladyfinger Cheese Cake', 'ingredients': ['1 pkg. ladyfingers', '8 oz. cream cheese', '1/2 c. sugar', '2 c. Cool Whip', '1 can Comstock pie filling (cherries or blueberries)'], 'directions': 'Combine cream cheese, sugar and Cool Whip. Pour into pie plate lined with ladyfingers. Refrigerate. When set, pour cherries (or blueberries) on pie. Makes 1 pie.', 'link': 'www.cookbooks.com/Recipe-Details.aspx?id=1057610', 'source': 'Gathered', 'NER': ['ladyfingers', 'cream cheese', 'sugar', 'Comstock pie filling'], 'website': 'www.cookbooks.com'}
# 1 pkg. ladyfingers
# ['ladyfingers', 'cream cheese', 'sugar', 'Comstock pie filling']
# (8257, 25.210549426069004)
# {'recipeID': 408763, 'title': 'Blueberry Pie', 'ingredients': ['1 pie crust', 'small amount chopped pecans', 'fresh blueberries, cooked, or canned pie filling', '8 oz. cream cheese', '8 oz. Cool Whip', '1 box confectioners sugar'], 'directions': 'Take pie crust, sprinkle pecans over the crust. Bake and cool. Cream together the cream cheese and sugar, then add Cool Whip. Pour into pie shell. Pour cooked blueberries over the pie; chill and serve.', 'link': 'www.cookbooks.com/Recipe-Details.aspx?id=913740', 'source': 'Gathered', 'NER': ['crust', 'amount', 'fresh blueberries', 'cream cheese', 'confectioners sugar'], 'website': 'www.cookbooks.com'}
# 1 pie crust
# ['crust', 'amount', 'fresh blueberries', 'cream cheese', 'confectioners sugar']
# (408763, 24.203660992767674)
# {'recipeID': 293926, 'title': 'Diabetic Apple Pie', 'ingredients': ['2 unbaked pie shells', 'apples', 'cinnamon', "Sweet 'N Low", 'butter'], 'directions': "Fill one pie shell as full as you like with cut up apples. Cover with butter and cinnamon. Add Sweet 'N Low if desirable. Take second pie shell and have it at room temperature.", 'link': 'www.cookbooks.com/Recipe-Details.aspx?id=919862', 'source': 'Gathered', 'NER': ['apples', 'cinnamon', 'N', 'butter'], 'website': 'www.cookbooks.com'}
# 2 unbaked pie shells
# ['apples', 'cinnamon', 'N', 'butter']
# (293926, 23.88519285061779)
# {'recipeID': 124486, 'title': 'Diabetic Apple Pie', 'ingredients': ['5 c. sliced apples', '2 tsp. tapioca', "2 Tbsp. or 8 pkg. Sweet 'N Low", 'cinnamon', "2 recipes Dieter's Pie Crust"], 'directions': "Roll 2/3 of pie crust to fit an 8-inch or 9-inch pie pan. Arrange apple slices in crust and sprinkle tapioca on top of apples, then sprinkle Sweet 'N Low and cinnamon on top. Roll out remaining pie crust, perforating the top and arrange over apples. Crimp edges securely, moistening with a little water, if necessary. Bake at 400\\u00b0 for 30 minutes or until apples are tender. One sixth of pie is 227 calories.", 'link': 'www.cookbooks.com/Recipe-Details.aspx?id=664276', 'source': 'Gathered', 'NER': ['apples', 'tapioca', 'N', 'cinnamon', 'Crust'], 'website': 'www.cookbooks.com'}
# 5 c. sliced apples
# ['apples', 'tapioca', 'N', 'cinnamon', 'Crust']
# (124486, 23.37641882805338)
# {'recipeID': 227756, 'title': 'Dutch Apple Pie', 'ingredients': ['4 apples (medium) peeled and diced', '3/4 cup sugar', '1 tsp. cinnamon', '2 Tbsp. flour', '1 Tbsp. butter'], 'directions': 'Spread apples in unbaked pie shell. Mix sugar, cinnamon, and flour. Pour over apples in unbaked pie shell. Add butter to top of mixture. Bake until apples are done.', 'link': 'www.cookbooks.com/Recipe-Details.aspx?id=122565', 'source': 'Gathered', 'NER': ['apples', 'sugar', 'cinnamon', 'flour', 'butter'], 'website': 'www.cookbooks.com'}
# 4 apples (medium) peeled and diced
# ['apples', 'sugar', 'cinnamon', 'flour', 'butter']
# (227756, 23.06351051048317)
# {'recipeID': 190623, 'title': 'Blueberry Pie', 'ingredients': ['1 baked 9-inch pie shell', '4 c. blueberries (fresh or frozen)', '1 c. sugar', '3 Tbsp. cornstarch', '1/4 tsp. salt', '1/4 c. water', '1 tsp. lemon juice'], 'directions': 'Line cooled pie shell with 2 cups blueberries.', 'link': 'www.cookbooks.com/Recipe-Details.aspx?id=363297', 'source': 'Gathered', 'NER': ['shell', 'blueberries', 'sugar', 'cornstarch', 'salt', 'water', 'lemon juice'], 'website': 'www.cookbooks.com'}
# 1 baked 9-inch pie shell
# ['shell', 'blueberries', 'sugar', 'cornstarch', 'salt', 'water', 'lemon juice']
# (190623, 23.011949882834326)
# {'recipeID': 522343, 'title': 'Fast Blueberry Pie', 'ingredients': ['1 baked 9-inch pie shell', '2 c. fresh or frozen blueberries', '1/2 c. powdered sugar', '1 c. whipping cream, whipped'], 'directions': 'Fill baked pie shell with blueberries. Sprinkle with powdered sugar and cover with whipped cream.', 'link': 'www.cookbooks.com/Recipe-Details.aspx?id=551166', 'source': 'Gathered', 'NER': ['shell', 'blueberries', 'powdered sugar', 'whipping cream'], 'website': 'www.cookbooks.com'}
# 1 baked 9-inch pie shell
# ['shell', 'blueberries', 'powdered sugar', 'whipping cream']
# (522343, 22.993799671156218)
# {'recipeID': 568638, 'title': "Tessie Coppley'S Open-Face Apple Pie", 'ingredients': ['4 c. apples, chopped fine', '3/4 c. sugar', '3 Tbsp. plain flour', '1/2 tsp. salt', '1/4 c. whipping cream (I use almost 1/2 cup to make more juice)', 'dash of apple pie spice'], 'directions': 'Put apples in unbaked 9-inch deep pie crust. Combine sugar, flour and salt; stir in cream. Pour mixture over apples; sprinkle with apple pie mix or cinnamon. Cover pie loosely with aluminum foil and bake in 375\\u00b0 oven for one hour. Remove foil and bake 15 minutes longer or until apples are tender.', 'link': 'www.cookbooks.com/Recipe-Details.aspx?id=327197', 'source': 'Gathered', 'NER': ['apples', 'sugar', 'flour', 'salt', 'whipping cream', 'apple pie spice'], 'website': 'www.cookbooks.com'}
# 4 c. apples, chopped fine
# ['apples', 'sugar', 'flour', 'salt', 'whipping cream', 'apple pie spice']
# (568638, 22.937364936462494)
# {'recipeID': 233308, 'title': 'Cherry Cream Cheese Pie', 'ingredients': ['1 8 oz. pkg. cream cheese, softened', '1/2 cup sugar', '8 oz. Cool Whip', '1 10 in. graham cracker crust', '21 oz. can cherry pie filling'], 'directions': 'Mix together cream cheese and sugar. Add Cool Whip and mix well. Put mixture into pie crust and top with 21 oz. can cherry pie filling. May also use blueberries.', 'link': 'www.cookbooks.com/Recipe-Details.aspx?id=148800', 'source': 'Gathered', 'NER': ['cream cheese', 'sugar', 'graham cracker crust', 'cherry pie filling'], 'website': 'www.cookbooks.com'}
# 1 8 oz. pkg. cream cheese, softened
# ['cream cheese', 'sugar', 'graham cracker crust', 'cherry pie filling']
# (233308, 22.77059654701253)
